# %%
! pip install requests ffmpeg-python
! pip install deepgram-sdk --upgrade
! pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: ffmpeg-python in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.7.4)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from ffmpeg-python) (1.0.0)
# Requirement already satisfied: deepgram-sdk in /usr/local/lib/python3.10/dist-packages (3.5.1)
# Requirement already satisfied: httpx>=0.25.2 in /usr/local/lib/python3.10/dist-packages (from deepgram-sdk) (0.27.2)
# Requirement already satisfied: websockets>=12.0 in /usr/local/lib/python3.10/dist-packages (from deepgram-sdk) (13.0)
# Requirement already satisfied: dataclasses-json>=0.6.3 in /usr/local/lib/python3.10/dist-packages (from deepgram-sdk) (0.6.7)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from deepgram-sdk) (4.12.2)
# Requirement already satisfied: aiohttp>=3.9.1 in /usr/local/lib/python3.10/dist-packages (from deepgram-sdk) (3.10.5)
# Requirement already satisfied: aiofiles>=23.2.1 in /usr/local/lib/python3.10/dist-packages (from deepgram-sdk) (24.1.0)
# Requirement already satisfied: aenum>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from deepgram-sdk) (3.1.15)
# Requirement already satisfied: deprecation>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from deepgram-sdk) (2.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.9.1->deepgram-sdk) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.9.1->deepgram-sdk) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.9.1->deepgram-sdk) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.9.1->deepgram-sdk) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.9.1->deepgram-sdk) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.9.1->deepgram-sdk) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp>=3.9.1->deepgram-sdk) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json>=0.6.3->deepgram-sdk) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json>=0.6.3->deepgram-sdk) (0.9.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from deprecation>=2.1.0->deepgram-sdk) (24.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.2->deepgram-sdk) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.2->deepgram-sdk) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.2->deepgram-sdk) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.2->deepgram-sdk) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.2->deepgram-sdk) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.25.2->deepgram-sdk) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json>=0.6.3->deepgram-sdk) (1.0.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.25.2->deepgram-sdk) (1.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.7.4)

# %%
from deepgram import DeepgramClient, PrerecordedOptions, FileSource
import base64
import json

# Deepgram API key
DG_KEY = "DG_API_KEY"

# Deepgram options for transcription
options = PrerecordedOptions(
    model="nova-2",
    smart_format=True,
    diarize=True,
)

# Initialize Deepgram client
deepgram = DeepgramClient(DG_KEY)

def transcribe_audio(buffer_data):
    try:
        # Prepare the audio payload for Deepgram
        payload: FileSource = {
            "buffer": buffer_data,
        }

        # Transcribe the audio file
        response = deepgram.listen.prerecorded.v("1").transcribe_file(payload, options)
        return response.to_dict()

    except Exception as e:
        print(f"Exception during transcription: {e}")
        return None

def process_transcription(transcript_data):
    try:
        # Extract the paragraphs
        paragraphs = transcript_data['results']['channels'][0]['alternatives'][0]['paragraphs']['paragraphs']

        # Prepare transcript text with Q: and A:
        transcript_text = ""
        for paragraph in paragraphs:
            speaker_label = "Q:" if paragraph['speaker'] == 0 else "A:"
            for sentence in paragraph['sentences']:
                transcript_text += f"{speaker_label} {sentence['text']}\n"

        return transcript_text

    except Exception as e:
        print(f"Exception during processing: {e}")
        return ""

def save_to_txt(transcript_text):
    try:
        # Save the transcript text to a .txt file
        with open('transcript.txt', 'w') as file:
            file.write(transcript_text)

        print("Transcript saved successfully.")

    except Exception as e:
        print(f"Exception during TXT saving: {e}")

def main():
    try:
        # Read the audio file
        with open('audio.mp3', 'rb') as audio_file:
            buffer_data = audio_file.read()

        # Transcribe the audio file
        transcript_data = transcribe_audio(buffer_data)

        if transcript_data:
            # Process transcription to get formatted transcript text
            transcript_text = process_transcription(transcript_data)

            # Save the transcript text to a .txt file
            save_to_txt(transcript_text)

    except Exception as e:
        print(f"Exception: {e}")

if __name__ == "__main__":
    main()
# Out:
# <ipython-input-8-d0bdf3c27fb8>:26: DeprecatedWarning: prerecorded is deprecated as of 3.4.0 and will be removed in 4.0.0. deepgram.listen.prerecorded is deprecated. Use deepgram.listen.rest instead.
#   response = deepgram.listen.prerecorded.v("1").transcribe_file(payload, options)
# Transcript saved successfully.

# %%
def print_transcript_file():
    try:
        # Read and print the content of the transcript.txt file
        with open('transcript.txt', 'r') as file:
            transcript_content = file.read()

        print("\n--- Transcript Content ---\n")
        print(transcript_content)

    except Exception as e:
        print(f"Exception while reading the file: {e}")

# Call the function to print the file content
print_transcript_file()
# Out:
# --- Transcript Content ---
#
# Q: I am interviewing Tulika.
# Q: Hi, Tulika.
# Q: Hello.
# Q: How are you?
# A: I'm good.
# Q: Can you tell me about your background including your age group, profession, and education level?
# A: I'm Tulika Giri currently pursuing pursuing GTech IT from Manipal University, Jaipur.
# A: My age is 21.
# Q: How would you describe your personality type?
# A: I'm socially selective and, like, I mostly am reserved around people.
# A: But if I like the vibe, I talk to.
# Q: How often do you experience stress or anxiety and what methods do you use to cope with it?
# A: I don't easily get stressed.
# A: But if I get stressed, I try to distract myself by watching some series or something.
# Q: Can you describe your overall mental health and any practices you engage in to maintain it?
# A: Overall mental health, I think I'm it's okay only.
# A: I'm not, like, very sad or depressed.
# A: I kind of try to be happy like I try to keep myself happy.
# A: That's my first priority.
# A: So if anything that is affecting me, I try to not think about it.
# A: Like, it doesn't matter in my life much that it can make me sad.
# Q: When solving problems, how do you typically approach the situation?
# Q: Can you give an example?
# Q: When solving problems, how do you typically approach the situation?
# Q: Can you give an example?
# Q: I approach
# A: I try to think of, like, different solution.
# A: Maybe I Google it or I think different solutions and then I compare them and I go with the good alternatives.
# Q: What factors do you consider most important when making a difficult decision?
# A: The easier one.
# A: Okay.
# A: The level of difficulty, like, which could be easy something like that.
# Q: How open are you to new ideas and experiences?
# Q: And can you provide an example of a recent new experience?
# A: Not very open to new ideas or experience.
# A: I don't know.
# A: I feel really scared.
# A: But I like to take risks, but not very good in general.
# A: Like, I like to do things that I normally do.
# Q: Do you prefer working alone or in a team and why?
# A: I prefer working in a team because I'm little laid back.
# A: I need someone to push me.
# Q: Okay.
# Q: How do you usually react to sudden changes in plans?
# Q: Can you share an example?
# A: I'm okay with it mostly because I, like, I try to understand other people's perspective.
# A: Like, they don't want to go, so it's okay.
# A: What about your perspective?
# A: I'm okay because it's okay.
# A: Like, if they don't want to go, so it's their choice.
# A: I cannot decide for them.
# Q: When faced with criticism, how do you typically respond and how do you use that feedback?
# A: I take it positively only.
# A: Like, I'd like to know about myself from other people's perspective.
# A: So I don't know.
# A: It's very exciting for me.
# A: Like, oh, they think this about me like that.
# Q: What is your emotional response when you achieve a goal, and how do you celebrate it?
# A: If I achieve a goal I don't know.
# A: I maybe I become a little happy, but I feel like if I have achieved it, anyone can.
# A: So I feel like that.
# Q: How do you handle failure, and what steps do you take afterwards?
# A: I don't know.
# A: I become a little sad then I distract myself.
# A: And then I think, okay, I have to work hard next time.
# Q: Do you dwell on it?
# Q: No.
# Q: Great.
# Q: When reflecting on past decisions, how do you feel about them and what have you learned from them?
# A: I think that, okay, this happened.
# A: I will learn from new experiences, but I mostly repeat the same mistakes sometimes.
# A: So I sometimes I learn from them.
# A: Sometimes I repeat them.
# A: So How do
# Q: you define success in your life and what measures do you use to evaluate it?
# A: Success is like if I think of it if it makes me happy for a, like, longer time, like, not just current happiness, like, I would be happy with it, but then I call it success.
# A: And, yeah, I try to celebrate it after I do check it.
# Q: How important is it for you to seek advice before making major decisions, and who do you usually turn to?
# A: Sometimes, like, it depends on the kind of, situation, like, that that kind of decision that I have to make.
# A: Mostly, I take advice from my father.
# A: Like, yeah, I trust his decisions.
# Q: I'll be giving you specific scenarios now.
# Q: Imagine you're working on an important project with a tight deadline and encountered an unexpected problem.
# Q: How will you handle this situation?
# A: I would get scared, and then I would calm myself down and try to get it done.
# A: Like, whatever I can do, I will do.
# Q: If you received criticism for a task you worked hard on, how would you feel and what actions would you take?
# A: I would ignore it.
# A: Like, I know what I have done.
# A: Like, if I like if I if I think it's, benefiting me, I will take it.
# A: But if I think it's coming from, like, lack of personality.
# Q: Given a choice between a secure job with moderate satisfaction and a risky job that could be highly fulfilling.
# Q: Which one would you choose and why?
# A: Secure job because not very open to new things.
# A: So I like to take risk, but not every time, like kind of risk that I know, like, okay.
# A: This can be the outcomes, and I can manage them.
# A: But if it's, like, very new or I don't know what can happen, uncertain, I won't do.
# Q: If you had the opportunity to move to a new city for a job that excites you, but that means leaving behind friends and family, how would you approach this decision?
# A: I would go to New City.
# A: Like, I can always come back home for some day.
# A: I will go to New City.
# Q: How would you handle a heated argument with a close friend?
# A: If there's an argument, I would try not like I would try to not speak for some time and then I will talk it out later.
# A: Like, I would give it some time to cool down and talk it out.
# Q: If you had the chance to invest in a startup that could either succeed greatly or fail completely, how would you evaluate this opportunity?
# A: I won't invest because then again, I'm not really risk taker.
# A: If it's very uncertain, I would invest.
# Q: How would you how do you balance work and personal life?
# Q: Can you describe a typical day?
# A: Not very good at balancing it.
# A: Still learning, but I would try to maybe divide time, but not not very much.
# Q: How often do you engage in social activities and what kind of activities do you prefer?
# A: Actually, I don't involve much in social activity.
# A: I'd like to be in my room watching series.
# Q: Do you prefer structured routines or spontaneous activities and why?
# A: Structured routine with some spontaneous activities.
# Q: How comfortable are you with taking risks?
# Q: And can you share an example of a recent risk you took?
# A: Recent risk I took.
# A: I haven't taken it, but I want to rent a self drive that car and go roam around in that.
# A: But some people are not agreeing with it.
# A: But yeah.
# Q: So you think you'll be comfortable with it because it's
# A: so risky?
# A: Yeah, because it is risky.
# A: But I know like the outcomes can be like I maybe I can crash it.
# A: But what can happen?
# A: I can crash it.
# Q: How important are emotions in your decision making process?
# Q: Can you provide an example?
# A: Not very emotional person.
# A: So I don't consider my emotion much.
# A: I suppress it mostly.
# A: More logical.
# Q: So more logical approach.
# Q: Okay.
# Q: What strategies do you use to stay motivated when working towards a long term
# A: goal?
# A: Long term goal.
# A: I get distracted very easily.
# A: So for motivation, maybe the outcome can be my motivation.
# A: Like, I will achieve this.
# A: So that may it keep me motivated.
# Q: How do you handle unexpected obstacles in your daily life?
# Q: Can you provide an example?
# A: Unexpected obstacle.
# A: I would ignore it.
# A: Maybe it depends on the kind of obstacle actually.
# Q: How important is it for you to maintain social connections and how do you nurture these relationships?
# A: Social connection.
# A: I'm not like very social person.
# A: So they're very fixed people that I hang out with.
# A: I like I don't very much feel like I'm the need to make new connections.
# A: So if I like the vibe, I will go with the floor.
# A: I won't talk to them much.
# Q: How would you describe intense physical attraction and how can it be distinguished from deeper emotional connections like love or affection?
# A: Can you repeat?
# Q: How would you describe intense physical attraction and how can it be distinguished from deeper emotional connections like love or affection?
# A: Okay.
# A: Physical love or affection is like very different from physical attraction.
# A: In physical attraction, you don't actually feel a connection.
# A: But in love you feel the connection.
# Q: So do you think you can love without being physically attracted to somebody?
# A: If I if you're talking about like relationship, if I love someone, I think physical attraction comes along automatically.
# A: Like, if you like the personality, if you love them, you will automatically feel physical attraction.
# Q: What are some effective ways to manage strong feelings of attraction particularly in context where they may not be appropriate?
# Q: What are some effective ways to manage strong feelings of attraction particularly in context where they may not be appropriate?
# A: Attraction.
# A: I don't get attracted very easily.
# A: So, if it's not appropriate, I won't get attracted.
# Q: Okay.
# Q: Can you share an experience where a strong attraction influenced your choices and how did you navigate that situation?
# A: No.
# A: It never affected my situation.
# Q: How often do you feel angry and what's typically triggers it for you?
# A: I don't get angry very easily.
# A: Like not very easily but if I get angry I would say very like mean things.
# A: So I try not to get angry, but if I get angry, it's very difficult to get back.
# Q: So do you suppress your anger?
# Q: Yes.
# Q: Okay.
# Q: How do you usually express your anger and what methods do you use to calm down?
# A: I try not to speak for some time.
# Q: How do you calm down?
# A: I don't know.
# A: I don't speak for some time and then I, like, try to understand the other people's perspective.
# A: Okay.
# A: So they did this because maybe that was the reason and then I count on automatic.
# Q: Can you provide an example of a situation where you managed your anger effectively?
# A: I try only.
# A: Like, I try to understand them, and I try not to speak.
# A: I don't know.
# A: I don't yeah.
# A: Even though I don't want to understand, I automatically try to understand.
# A: Like, it's okay.
# A: What's the point to say?
# A: Like, don't be the bad person.
# Q: How do you define greed and in what ways do you see it manifest in your life?
# A: Greed.
# A: Like money.
# A: Money is important.
# A: Motivation maybe like for goals, need money.
# Q: So how do you balance ambition and greed in your personal and professional life?
# A: I think they are very interconnected even for me.
# A: Like, ambition ambitious comes from me.
# Q: Can you share an experience where greed negatively impacted your relationships or decisions?
# A: No.
# A: Like, I'm not that greedy.
# A: So
# Q: How do you define attachment and how do you differentiate it from dependence?
# A: Attachment, for me is like connection.
# A: Like, when I feel good connection with them, but dependence is like when I trust the other person very much, then I feel very dependent on them.
# A: Like I can be dependent on them.
# A: But when I'm attached to someone, I'm not actually very dependent on them.
# A: There's just a connection.
# A: So how
# Q: do you manage attachments in your life, especially in relationships?
# A: I don't get attached very easily.
# A: Like, I take a lot of time to get attached.
# A: So I don't know.
# A: It doesn't matter much.
# A: Like I can be attached also.
# Q: Can you describe a situation where an attachment caused a challenge for you?
# Q: How often do you experience feelings of jealousy and what usually triggers them?
# A: Jealousy jealousy, like, comes only when you, like, you have some sort of expectations.
# A: Like right?
# A: So I don't, like, feel like I don't think that I should expect something from everyone.
# A: So I feel like it's okay.
# A: Their life, it's okay.
# Q: How do you cope with feelings of insecurity in your personal and professional life?
# A: I'm not, like, very insecure.
# A: I'm, like, more of a okay.
# A: I'm good.
# A: Like that only.
# A: So if I get insecure, I try to say, like, no, it's okay.
# A: I'm nice or it doesn't matter.
# Q: Can you provide an example of how you overcame a situation where jealousy or insecurity was affecting you?
# A: I don't know.
# A: As I said, I suppress my feelings, so maybe I would ignore it.
# A: Something like
# Q: that.
# Q: So does it mean that you actually overcame
# A: Unfamiliar, maybe okay.
# A: So it depends on the situation, but if it's very unfamiliar, I would be a little scared.
# A: But it's okay.
# A: If it's unfamiliar, maybe it will teach me something.
# A: So a little excited.
# A: But scared.
# Q: What strategies do you use to build confidence in areas where you feel less knowledgeable?
# A: If I feel less knowledgeable, then, yeah, then I would gain some knowledge.
# A: So that would be my confidence.
# A: Okay.
# A: I will gain something.
# Q: Can you share a time when you successfully navigated an unknown situation and how you built your confidence to do so?
# A: So if there's an unfamiliar situation, I don't know.
# A: I haven't encountered much.
# A: Or if I ever encounter it, I try to escape from it or something like that because I live in the present, not in the future.
# A: I don't think about my future much.
# A: So, yeah, if I ever encounter it, I mean, depends on the situation also.
# A: But if I have to face it, then I would face it.
# A: Like, it's okay.
# A: I won't do it.
# A: Like, something like that.
# Q: Do you feel this interview accurately captures your mental health and behavior?
# A: A little bit.
# A: Well, like fully, but yeah.
# Q: Were you completely honest while answering?
# Q: Yes.
# Q: Did you at any point feel uncomfortable?
# Q: Great.
# Q: Thank you, Thalika.
# A: Thank you.

# %%
# Code to process the transcript file and generate a modified version
# Importing the necessary library
import re

# Reading the transcript from the file
with open('transcript.txt', 'r') as file:
    lines = file.readlines()

# Initializing variables to store the combined Q and A
combined_q = ''
combined_a = ''
result = []

# Processing each line
for line in lines:
    line = line.strip()  # Remove leading and trailing whitespace
    if line.startswith('Q:'):
        if combined_a:  # Save the previous combined A before starting a new Q
            result.append(f'A: {combined_a.strip()}')
            combined_a = ''
        combined_q += ' ' + line[2:].strip()  # Combine Q lines
    elif line.startswith('A:'):
        if combined_q:  # Save the previous combined Q before starting a new A
            result.append(f'Q: {combined_q.strip()}')
            combined_q = ''
        combined_a += ' ' + line[2:].strip()  # Combine A lines

# Append any remaining combined Q or A
if combined_q:
    result.append(f'Q: {combined_q.strip()}')
if combined_a:
    result.append(f'A: {combined_a.strip()}')

# Write the result to a new file
with open('new_transcript.txt', 'w') as file:
    for line in result:
        file.write(line + '\n')

# Print the output file content
with open('new_transcript.txt', 'r') as file:
    print(file.read())
# Out:
# Q: I am interviewing Tulika. Hi, Tulika. Hello. How are you?
# A: I'm good.
# Q: Can you tell me about your background including your age group, profession, and education level?
# A: I'm Tulika Giri currently pursuing pursuing GTech IT from Manipal University, Jaipur. My age is 21.
# Q: How would you describe your personality type?
# A: I'm socially selective and, like, I mostly am reserved around people. But if I like the vibe, I talk to.
# Q: How often do you experience stress or anxiety and what methods do you use to cope with it?
# A: I don't easily get stressed. But if I get stressed, I try to distract myself by watching some series or something.
# Q: Can you describe your overall mental health and any practices you engage in to maintain it?
# A: Overall mental health, I think I'm it's okay only. I'm not, like, very sad or depressed. I kind of try to be happy like I try to keep myself happy. That's my first priority. So if anything that is affecting me, I try to not think about it. Like, it doesn't matter in my life much that it can make me sad.
# Q: When solving problems, how do you typically approach the situation? Can you give an example? When solving problems, how do you typically approach the situation? Can you give an example? I approach
# A: I try to think of, like, different solution. Maybe I Google it or I think different solutions and then I compare them and I go with the good alternatives.
# Q: What factors do you consider most important when making a difficult decision?
# A: The easier one. Okay. The level of difficulty, like, which could be easy something like that.
# Q: How open are you to new ideas and experiences? And can you provide an example of a recent new experience?
# A: Not very open to new ideas or experience. I don't know. I feel really scared. But I like to take risks, but not very good in general. Like, I like to do things that I normally do.
# Q: Do you prefer working alone or in a team and why?
# A: I prefer working in a team because I'm little laid back. I need someone to push me.
# Q: Okay. How do you usually react to sudden changes in plans? Can you share an example?
# A: I'm okay with it mostly because I, like, I try to understand other people's perspective. Like, they don't want to go, so it's okay. What about your perspective? I'm okay because it's okay. Like, if they don't want to go, so it's their choice. I cannot decide for them.
# Q: When faced with criticism, how do you typically respond and how do you use that feedback?
# A: I take it positively only. Like, I'd like to know about myself from other people's perspective. So I don't know. It's very exciting for me. Like, oh, they think this about me like that.
# Q: What is your emotional response when you achieve a goal, and how do you celebrate it?
# A: If I achieve a goal I don't know. I maybe I become a little happy, but I feel like if I have achieved it, anyone can. So I feel like that.
# Q: How do you handle failure, and what steps do you take afterwards?
# A: I don't know. I become a little sad then I distract myself. And then I think, okay, I have to work hard next time.
# Q: Do you dwell on it? No. Great. When reflecting on past decisions, how do you feel about them and what have you learned from them?
# A: I think that, okay, this happened. I will learn from new experiences, but I mostly repeat the same mistakes sometimes. So I sometimes I learn from them. Sometimes I repeat them. So How do
# Q: you define success in your life and what measures do you use to evaluate it?
# A: Success is like if I think of it if it makes me happy for a, like, longer time, like, not just current happiness, like, I would be happy with it, but then I call it success. And, yeah, I try to celebrate it after I do check it.
# Q: How important is it for you to seek advice before making major decisions, and who do you usually turn to?
# A: Sometimes, like, it depends on the kind of, situation, like, that that kind of decision that I have to make. Mostly, I take advice from my father. Like, yeah, I trust his decisions.
# Q: I'll be giving you specific scenarios now. Imagine you're working on an important project with a tight deadline and encountered an unexpected problem. How will you handle this situation?
# A: I would get scared, and then I would calm myself down and try to get it done. Like, whatever I can do, I will do.
# Q: If you received criticism for a task you worked hard on, how would you feel and what actions would you take?
# A: I would ignore it. Like, I know what I have done. Like, if I like if I if I think it's, benefiting me, I will take it. But if I think it's coming from, like, lack of personality.
# Q: Given a choice between a secure job with moderate satisfaction and a risky job that could be highly fulfilling. Which one would you choose and why?
# A: Secure job because not very open to new things. So I like to take risk, but not every time, like kind of risk that I know, like, okay. This can be the outcomes, and I can manage them. But if it's, like, very new or I don't know what can happen, uncertain, I won't do.
# Q: If you had the opportunity to move to a new city for a job that excites you, but that means leaving behind friends and family, how would you approach this decision?
# A: I would go to New City. Like, I can always come back home for some day. I will go to New City.
# Q: How would you handle a heated argument with a close friend?
# A: If there's an argument, I would try not like I would try to not speak for some time and then I will talk it out later. Like, I would give it some time to cool down and talk it out.
# Q: If you had the chance to invest in a startup that could either succeed greatly or fail completely, how would you evaluate this opportunity?
# A: I won't invest because then again, I'm not really risk taker. If it's very uncertain, I would invest.
# Q: How would you how do you balance work and personal life? Can you describe a typical day?
# A: Not very good at balancing it. Still learning, but I would try to maybe divide time, but not not very much.
# Q: How often do you engage in social activities and what kind of activities do you prefer?
# A: Actually, I don't involve much in social activity. I'd like to be in my room watching series.
# Q: Do you prefer structured routines or spontaneous activities and why?
# A: Structured routine with some spontaneous activities.
# Q: How comfortable are you with taking risks? And can you share an example of a recent risk you took?
# A: Recent risk I took. I haven't taken it, but I want to rent a self drive that car and go roam around in that. But some people are not agreeing with it. But yeah.
# Q: So you think you'll be comfortable with it because it's
# A: so risky? Yeah, because it is risky. But I know like the outcomes can be like I maybe I can crash it. But what can happen? I can crash it.
# Q: How important are emotions in your decision making process? Can you provide an example?
# A: Not very emotional person. So I don't consider my emotion much. I suppress it mostly. More logical.
# Q: So more logical approach. Okay. What strategies do you use to stay motivated when working towards a long term
# A: goal? Long term goal. I get distracted very easily. So for motivation, maybe the outcome can be my motivation. Like, I will achieve this. So that may it keep me motivated.
# Q: How do you handle unexpected obstacles in your daily life? Can you provide an example?
# A: Unexpected obstacle. I would ignore it. Maybe it depends on the kind of obstacle actually.
# Q: How important is it for you to maintain social connections and how do you nurture these relationships?
# A: Social connection. I'm not like very social person. So they're very fixed people that I hang out with. I like I don't very much feel like I'm the need to make new connections. So if I like the vibe, I will go with the floor. I won't talk to them much.
# Q: How would you describe intense physical attraction and how can it be distinguished from deeper emotional connections like love or affection?
# A: Can you repeat?
# Q: How would you describe intense physical attraction and how can it be distinguished from deeper emotional connections like love or affection?
# A: Okay. Physical love or affection is like very different from physical attraction. In physical attraction, you don't actually feel a connection. But in love you feel the connection.
# Q: So do you think you can love without being physically attracted to somebody?
# A: If I if you're talking about like relationship, if I love someone, I think physical attraction comes along automatically. Like, if you like the personality, if you love them, you will automatically feel physical attraction.
# Q: What are some effective ways to manage strong feelings of attraction particularly in context where they may not be appropriate? What are some effective ways to manage strong feelings of attraction particularly in context where they may not be appropriate?
# A: Attraction. I don't get attracted very easily. So, if it's not appropriate, I won't get attracted.
# Q: Okay. Can you share an experience where a strong attraction influenced your choices and how did you navigate that situation?
# A: No. It never affected my situation.
# Q: How often do you feel angry and what's typically triggers it for you?
# A: I don't get angry very easily. Like not very easily but if I get angry I would say very like mean things. So I try not to get angry, but if I get angry, it's very difficult to get back.
# Q: So do you suppress your anger? Yes. Okay. How do you usually express your anger and what methods do you use to calm down?
# A: I try not to speak for some time.
# Q: How do you calm down?
# A: I don't know. I don't speak for some time and then I, like, try to understand the other people's perspective. Okay. So they did this because maybe that was the reason and then I count on automatic.
# Q: Can you provide an example of a situation where you managed your anger effectively?
# A: I try only. Like, I try to understand them, and I try not to speak. I don't know. I don't yeah. Even though I don't want to understand, I automatically try to understand. Like, it's okay. What's the point to say? Like, don't be the bad person.
# Q: How do you define greed and in what ways do you see it manifest in your life?
# A: Greed. Like money. Money is important. Motivation maybe like for goals, need money.
# Q: So how do you balance ambition and greed in your personal and professional life?
# A: I think they are very interconnected even for me. Like, ambition ambitious comes from me.
# Q: Can you share an experience where greed negatively impacted your relationships or decisions?
# A: No. Like, I'm not that greedy. So
# Q: How do you define attachment and how do you differentiate it from dependence?
# A: Attachment, for me is like connection. Like, when I feel good connection with them, but dependence is like when I trust the other person very much, then I feel very dependent on them. Like I can be dependent on them. But when I'm attached to someone, I'm not actually very dependent on them. There's just a connection. So how
# Q: do you manage attachments in your life, especially in relationships?
# A: I don't get attached very easily. Like, I take a lot of time to get attached. So I don't know. It doesn't matter much. Like I can be attached also.
# Q: Can you describe a situation where an attachment caused a challenge for you? How often do you experience feelings of jealousy and what usually triggers them?
# A: Jealousy jealousy, like, comes only when you, like, you have some sort of expectations. Like right? So I don't, like, feel like I don't think that I should expect something from everyone. So I feel like it's okay. Their life, it's okay.
# Q: How do you cope with feelings of insecurity in your personal and professional life?
# A: I'm not, like, very insecure. I'm, like, more of a okay. I'm good. Like that only. So if I get insecure, I try to say, like, no, it's okay. I'm nice or it doesn't matter.
# Q: Can you provide an example of how you overcame a situation where jealousy or insecurity was affecting you?
# A: I don't know. As I said, I suppress my feelings, so maybe I would ignore it. Something like
# Q: that. So does it mean that you actually overcame
# A: Unfamiliar, maybe okay. So it depends on the situation, but if it's very unfamiliar, I would be a little scared. But it's okay. If it's unfamiliar, maybe it will teach me something. So a little excited. But scared.
# Q: What strategies do you use to build confidence in areas where you feel less knowledgeable?
# A: If I feel less knowledgeable, then, yeah, then I would gain some knowledge. So that would be my confidence. Okay. I will gain something.
# Q: Can you share a time when you successfully navigated an unknown situation and how you built your confidence to do so?
# A: So if there's an unfamiliar situation, I don't know. I haven't encountered much. Or if I ever encounter it, I try to escape from it or something like that because I live in the present, not in the future. I don't think about my future much. So, yeah, if I ever encounter it, I mean, depends on the situation also. But if I have to face it, then I would face it. Like, it's okay. I won't do it. Like, something like that.
# Q: Do you feel this interview accurately captures your mental health and behavior?
# A: A little bit. Well, like fully, but yeah.
# Q: Were you completely honest while answering? Yes. Did you at any point feel uncomfortable? Great. Thank you, Thalika.
# A: Thank you.

# %%
import csv

# Read the modified transcript from new_transcript.txt
with open('new_transcript.txt', 'r') as file:
    lines = file.readlines()

# Initialize variables to store questions and answers
questions = []
answers = []

# Process each line to separate Q: and A:
for line in lines:
    line = line.strip()  # Remove leading and trailing whitespace
    if line.startswith('Q:'):
        questions.append(line[2:].strip())  # Store the question (without the Q: prefix)
    elif line.startswith('A:'):
        answers.append(line[2:].strip())  # Store the answer (without the A: prefix)

# Write the questions and answers to a CSV file
with open('test.csv', 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(['Question', 'Answer'])  # Write the header row

    # Assuming each question has a corresponding answer
    for q, a in zip(questions, answers):
        csvwriter.writerow([q, a])  # Write each question and its corresponding answer

# Print the content of the CSV file
with open('test.csv', 'r') as file:
    print(file.read())
# Out:
# Question,Answer
# "I am interviewing Tulika. Hi, Tulika. Hello. How are you?",I'm good.
# "Can you tell me about your background including your age group, profession, and education level?","I'm Tulika Giri currently pursuing pursuing GTech IT from Manipal University, Jaipur. My age is 21."
# How would you describe your personality type?,"I'm socially selective and, like, I mostly am reserved around people. But if I like the vibe, I talk to."
# How often do you experience stress or anxiety and what methods do you use to cope with it?,"I don't easily get stressed. But if I get stressed, I try to distract myself by watching some series or something."
# Can you describe your overall mental health and any practices you engage in to maintain it?,"Overall mental health, I think I'm it's okay only. I'm not, like, very sad or depressed. I kind of try to be happy like I try to keep myself happy. That's my first priority. So if anything that is affecting me, I try to not think about it. Like, it doesn't matter in my life much that it can make me sad."
# "When solving problems, how do you typically approach the situation? Can you give an example? When solving problems, how do you typically approach the situation? Can you give an example? I approach","I try to think of, like, different solution. Maybe I Google it or I think different solutions and then I compare them and I go with the good alternatives."
# What factors do you consider most important when making a difficult decision?,"The easier one. Okay. The level of difficulty, like, which could be easy something like that."
# How open are you to new ideas and experiences? And can you provide an example of a recent new experience?,"Not very open to new ideas or experience. I don't know. I feel really scared. But I like to take risks, but not very good in general. Like, I like to do things that I normally do."
# Do you prefer working alone or in a team and why?,I prefer working in a team because I'm little laid back. I need someone to push me.
# Okay. How do you usually react to sudden changes in plans? Can you share an example?,"I'm okay with it mostly because I, like, I try to understand other people's perspective. Like, they don't want to go, so it's okay. What about your perspective? I'm okay because it's okay. Like, if they don't want to go, so it's their choice. I cannot decide for them."
# "When faced with criticism, how do you typically respond and how do you use that feedback?","I take it positively only. Like, I'd like to know about myself from other people's perspective. So I don't know. It's very exciting for me. Like, oh, they think this about me like that."
# "What is your emotional response when you achieve a goal, and how do you celebrate it?","If I achieve a goal I don't know. I maybe I become a little happy, but I feel like if I have achieved it, anyone can. So I feel like that."
# "How do you handle failure, and what steps do you take afterwards?","I don't know. I become a little sad then I distract myself. And then I think, okay, I have to work hard next time."
# "Do you dwell on it? No. Great. When reflecting on past decisions, how do you feel about them and what have you learned from them?","I think that, okay, this happened. I will learn from new experiences, but I mostly repeat the same mistakes sometimes. So I sometimes I learn from them. Sometimes I repeat them. So How do"
# you define success in your life and what measures do you use to evaluate it?,"Success is like if I think of it if it makes me happy for a, like, longer time, like, not just current happiness, like, I would be happy with it, but then I call it success. And, yeah, I try to celebrate it after I do check it."
# "How important is it for you to seek advice before making major decisions, and who do you usually turn to?","Sometimes, like, it depends on the kind of, situation, like, that that kind of decision that I have to make. Mostly, I take advice from my father. Like, yeah, I trust his decisions."
# I'll be giving you specific scenarios now. Imagine you're working on an important project with a tight deadline and encountered an unexpected problem. How will you handle this situation?,"I would get scared, and then I would calm myself down and try to get it done. Like, whatever I can do, I will do."
# "If you received criticism for a task you worked hard on, how would you feel and what actions would you take?","I would ignore it. Like, I know what I have done. Like, if I like if I if I think it's, benefiting me, I will take it. But if I think it's coming from, like, lack of personality."
# Given a choice between a secure job with moderate satisfaction and a risky job that could be highly fulfilling. Which one would you choose and why?,"Secure job because not very open to new things. So I like to take risk, but not every time, like kind of risk that I know, like, okay. This can be the outcomes, and I can manage them. But if it's, like, very new or I don't know what can happen, uncertain, I won't do."
# "If you had the opportunity to move to a new city for a job that excites you, but that means leaving behind friends and family, how would you approach this decision?","I would go to New City. Like, I can always come back home for some day. I will go to New City."
# How would you handle a heated argument with a close friend?,"If there's an argument, I would try not like I would try to not speak for some time and then I will talk it out later. Like, I would give it some time to cool down and talk it out."
# "If you had the chance to invest in a startup that could either succeed greatly or fail completely, how would you evaluate this opportunity?","I won't invest because then again, I'm not really risk taker. If it's very uncertain, I would invest."
# How would you how do you balance work and personal life? Can you describe a typical day?,"Not very good at balancing it. Still learning, but I would try to maybe divide time, but not not very much."
# How often do you engage in social activities and what kind of activities do you prefer?,"Actually, I don't involve much in social activity. I'd like to be in my room watching series."
# Do you prefer structured routines or spontaneous activities and why?,Structured routine with some spontaneous activities.
# How comfortable are you with taking risks? And can you share an example of a recent risk you took?,"Recent risk I took. I haven't taken it, but I want to rent a self drive that car and go roam around in that. But some people are not agreeing with it. But yeah."
# So you think you'll be comfortable with it because it's,"so risky? Yeah, because it is risky. But I know like the outcomes can be like I maybe I can crash it. But what can happen? I can crash it."
# How important are emotions in your decision making process? Can you provide an example?,Not very emotional person. So I don't consider my emotion much. I suppress it mostly. More logical.
# So more logical approach. Okay. What strategies do you use to stay motivated when working towards a long term,"goal? Long term goal. I get distracted very easily. So for motivation, maybe the outcome can be my motivation. Like, I will achieve this. So that may it keep me motivated."
# How do you handle unexpected obstacles in your daily life? Can you provide an example?,Unexpected obstacle. I would ignore it. Maybe it depends on the kind of obstacle actually.
# How important is it for you to maintain social connections and how do you nurture these relationships?,"Social connection. I'm not like very social person. So they're very fixed people that I hang out with. I like I don't very much feel like I'm the need to make new connections. So if I like the vibe, I will go with the floor. I won't talk to them much."
# How would you describe intense physical attraction and how can it be distinguished from deeper emotional connections like love or affection?,Can you repeat?
# How would you describe intense physical attraction and how can it be distinguished from deeper emotional connections like love or affection?,"Okay. Physical love or affection is like very different from physical attraction. In physical attraction, you don't actually feel a connection. But in love you feel the connection."
# So do you think you can love without being physically attracted to somebody?,"If I if you're talking about like relationship, if I love someone, I think physical attraction comes along automatically. Like, if you like the personality, if you love them, you will automatically feel physical attraction."
# What are some effective ways to manage strong feelings of attraction particularly in context where they may not be appropriate? What are some effective ways to manage strong feelings of attraction particularly in context where they may not be appropriate?,"Attraction. I don't get attracted very easily. So, if it's not appropriate, I won't get attracted."
# Okay. Can you share an experience where a strong attraction influenced your choices and how did you navigate that situation?,No. It never affected my situation.
# How often do you feel angry and what's typically triggers it for you?,"I don't get angry very easily. Like not very easily but if I get angry I would say very like mean things. So I try not to get angry, but if I get angry, it's very difficult to get back."
# So do you suppress your anger? Yes. Okay. How do you usually express your anger and what methods do you use to calm down?,I try not to speak for some time.
# How do you calm down?,"I don't know. I don't speak for some time and then I, like, try to understand the other people's perspective. Okay. So they did this because maybe that was the reason and then I count on automatic."
# Can you provide an example of a situation where you managed your anger effectively?,"I try only. Like, I try to understand them, and I try not to speak. I don't know. I don't yeah. Even though I don't want to understand, I automatically try to understand. Like, it's okay. What's the point to say? Like, don't be the bad person."
# How do you define greed and in what ways do you see it manifest in your life?,"Greed. Like money. Money is important. Motivation maybe like for goals, need money."
# So how do you balance ambition and greed in your personal and professional life?,"I think they are very interconnected even for me. Like, ambition ambitious comes from me."
# Can you share an experience where greed negatively impacted your relationships or decisions?,"No. Like, I'm not that greedy. So"
# How do you define attachment and how do you differentiate it from dependence?,"Attachment, for me is like connection. Like, when I feel good connection with them, but dependence is like when I trust the other person very much, then I feel very dependent on them. Like I can be dependent on them. But when I'm attached to someone, I'm not actually very dependent on them. There's just a connection. So how"
# "do you manage attachments in your life, especially in relationships?","I don't get attached very easily. Like, I take a lot of time to get attached. So I don't know. It doesn't matter much. Like I can be attached also."
# Can you describe a situation where an attachment caused a challenge for you? How often do you experience feelings of jealousy and what usually triggers them?,"Jealousy jealousy, like, comes only when you, like, you have some sort of expectations. Like right? So I don't, like, feel like I don't think that I should expect something from everyone. So I feel like it's okay. Their life, it's okay."
# How do you cope with feelings of insecurity in your personal and professional life?,"I'm not, like, very insecure. I'm, like, more of a okay. I'm good. Like that only. So if I get insecure, I try to say, like, no, it's okay. I'm nice or it doesn't matter."
# Can you provide an example of how you overcame a situation where jealousy or insecurity was affecting you?,"I don't know. As I said, I suppress my feelings, so maybe I would ignore it. Something like"
# that. So does it mean that you actually overcame,"Unfamiliar, maybe okay. So it depends on the situation, but if it's very unfamiliar, I would be a little scared. But it's okay. If it's unfamiliar, maybe it will teach me something. So a little excited. But scared."
# What strategies do you use to build confidence in areas where you feel less knowledgeable?,"If I feel less knowledgeable, then, yeah, then I would gain some knowledge. So that would be my confidence. Okay. I will gain something."
# Can you share a time when you successfully navigated an unknown situation and how you built your confidence to do so?,"So if there's an unfamiliar situation, I don't know. I haven't encountered much. Or if I ever encounter it, I try to escape from it or something like that because I live in the present, not in the future. I don't think about my future much. So, yeah, if I ever encounter it, I mean, depends on the situation also. But if I have to face it, then I would face it. Like, it's okay. I won't do it. Like, something like that."
# Do you feel this interview accurately captures your mental health and behavior?,"A little bit. Well, like fully, but yeah."
# "Were you completely honest while answering? Yes. Did you at any point feel uncomfortable? Great. Thank you, Thalika.",Thank you.

# %%
# !pip install sentence-transformers


import csv
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from collections import defaultdict

# Load the pre-trained model
model = SentenceTransformer('distilbert-base-nli-mean-tokens')

# Load the CSV file
questions = []
answers = []
with open('test.csv', mode='r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        questions.append(row['Question'])
        answers.append(row['Answer'])

# Encode all questions
encodings = model.encode(questions)

# Set threshold for cosine similarity
threshold = 0.50
group_assignment = [-1] * len(questions)  # Initialize group assignment with -1

group_id = 0
group_assignment[0] = group_id  # Start with the first question in group 0

# Process the questions and group them
for i in range(1, len(questions)):
    # Check if the current question contains "next" and "question"
    if "next" in questions[i].lower() and "question" in questions[i].lower():
        group_id += 1  # Start a new group
        group_assignment[i] = group_id
    else:
        # Calculate similarity with the previous question
        similarity = cosine_similarity([encodings[i]], [encodings[i-1]])[0][0]

        if similarity > threshold:
            group_assignment[i] = group_id  # Assign to the current group
        else:
            group_id += 1  # Start a new group
            group_assignment[i] = group_id

# Create groups with Main Question and Follow-up Questions
groups = defaultdict(list)
for idx, group in enumerate(group_assignment):
    groups[group].append(idx)

# Write the grouped questions to final.txt with Scenario labels
with open('final.txt', 'w') as outfile:
    for group, indices in groups.items():
        if len(indices) > 1:
            outfile.write(f"\nScenario 1 (Group {group + 1}):\n")
        else:
            outfile.write(f"\nScenario 0 (Group {group + 1}):\n")

        if indices:
            main_question_idx = indices[0]
            outfile.write(f"Main Question: {questions[main_question_idx]}\n")
            outfile.write(f"Answer: {answers[main_question_idx]}\n")
            for idx in indices[1:]:
                outfile.write(f"Follow-up Question: {questions[idx]}\n")
                outfile.write(f"Answer: {answers[idx]}\n")

# Print the grouped questions to console with Scenario labels
for group, indices in groups.items():
    if len(indices) > 1:
        print(f"\nScenario 1 (Group {group + 1}):")
    else:
        print(f"\nScenario 0 (Group {group + 1}):")

    if indices:
        main_question_idx = indices[0]
        print(f"Main Question: {questions[main_question_idx]}")
        print(f"Answer: {answers[main_question_idx]}")
        for idx in indices[1:]:
            print(f"Follow-up Question: {questions[idx]}")
            print(f"Answer: {answers[idx]}")
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (3.0.1)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.42.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.4.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.3.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
#
# Scenario 0 (Group 1):
# Main Question: I am interviewing Tulika. Hi, Tulika. Hello. How are you?
# Answer: I'm good.
#
# Scenario 1 (Group 2):
# Main Question: Can you tell me about your background including your age group, profession, and education level?
# Answer: I'm Tulika Giri currently pursuing pursuing GTech IT from Manipal University, Jaipur. My age is 21.
# Follow-up Question: How would you describe your personality type?
# Answer: I'm socially selective and, like, I mostly am reserved around people. But if I like the vibe, I talk to.
# Follow-up Question: How often do you experience stress or anxiety and what methods do you use to cope with it?
# Answer: I don't easily get stressed. But if I get stressed, I try to distract myself by watching some series or something.
# Follow-up Question: Can you describe your overall mental health and any practices you engage in to maintain it?
# Answer: Overall mental health, I think I'm it's okay only. I'm not, like, very sad or depressed. I kind of try to be happy like I try to keep myself happy. That's my first priority. So if anything that is affecting me, I try to not think about it. Like, it doesn't matter in my life much that it can make me sad.
# Follow-up Question: When solving problems, how do you typically approach the situation? Can you give an example? When solving problems, how do you typically approach the situation? Can you give an example? I approach
# Answer: I try to think of, like, different solution. Maybe I Google it or I think different solutions and then I compare them and I go with the good alternatives.
# Follow-up Question: What factors do you consider most important when making a difficult decision?
# Answer: The easier one. Okay. The level of difficulty, like, which could be easy something like that.
#
# Scenario 0 (Group 3):
# Main Question: How open are you to new ideas and experiences? And can you provide an example of a recent new experience?
# Answer: Not very open to new ideas or experience. I don't know. I feel really scared. But I like to take risks, but not very good in general. Like, I like to do things that I normally do.
#
# Scenario 0 (Group 4):
# Main Question: Do you prefer working alone or in a team and why?
# Answer: I prefer working in a team because I'm little laid back. I need someone to push me.
#
# Scenario 1 (Group 5):
# Main Question: Okay. How do you usually react to sudden changes in plans? Can you share an example?
# Answer: I'm okay with it mostly because I, like, I try to understand other people's perspective. Like, they don't want to go, so it's okay. What about your perspective? I'm okay because it's okay. Like, if they don't want to go, so it's their choice. I cannot decide for them.
# Follow-up Question: When faced with criticism, how do you typically respond and how do you use that feedback?
# Answer: I take it positively only. Like, I'd like to know about myself from other people's perspective. So I don't know. It's very exciting for me. Like, oh, they think this about me like that.
# Follow-up Question: What is your emotional response when you achieve a goal, and how do you celebrate it?
# Answer: If I achieve a goal I don't know. I maybe I become a little happy, but I feel like if I have achieved it, anyone can. So I feel like that.
# Follow-up Question: How do you handle failure, and what steps do you take afterwards?
# Answer: I don't know. I become a little sad then I distract myself. And then I think, okay, I have to work hard next time.
# Follow-up Question: Do you dwell on it? No. Great. When reflecting on past decisions, how do you feel about them and what have you learned from them?
# Answer: I think that, okay, this happened. I will learn from new experiences, but I mostly repeat the same mistakes sometimes. So I sometimes I learn from them. Sometimes I repeat them. So How do
# Follow-up Question: you define success in your life and what measures do you use to evaluate it?
# Answer: Success is like if I think of it if it makes me happy for a, like, longer time, like, not just current happiness, like, I would be happy with it, but then I call it success. And, yeah, I try to celebrate it after I do check it.
# Follow-up Question: How important is it for you to seek advice before making major decisions, and who do you usually turn to?
# Answer: Sometimes, like, it depends on the kind of, situation, like, that that kind of decision that I have to make. Mostly, I take advice from my father. Like, yeah, I trust his decisions.
# Follow-up Question: I'll be giving you specific scenarios now. Imagine you're working on an important project with a tight deadline and encountered an unexpected problem. How will you handle this situation?
# Answer: I would get scared, and then I would calm myself down and try to get it done. Like, whatever I can do, I will do.
# Follow-up Question: If you received criticism for a task you worked hard on, how would you feel and what actions would you take?
# Answer: I would ignore it. Like, I know what I have done. Like, if I like if I if I think it's, benefiting me, I will take it. But if I think it's coming from, like, lack of personality.
# Follow-up Question: Given a choice between a secure job with moderate satisfaction and a risky job that could be highly fulfilling. Which one would you choose and why?
# Answer: Secure job because not very open to new things. So I like to take risk, but not every time, like kind of risk that I know, like, okay. This can be the outcomes, and I can manage them. But if it's, like, very new or I don't know what can happen, uncertain, I won't do.
# Follow-up Question: If you had the opportunity to move to a new city for a job that excites you, but that means leaving behind friends and family, how would you approach this decision?
# Answer: I would go to New City. Like, I can always come back home for some day. I will go to New City.
#
# Scenario 0 (Group 6):
# Main Question: How would you handle a heated argument with a close friend?
# Answer: If there's an argument, I would try not like I would try to not speak for some time and then I will talk it out later. Like, I would give it some time to cool down and talk it out.
#
# Scenario 0 (Group 7):
# Main Question: If you had the chance to invest in a startup that could either succeed greatly or fail completely, how would you evaluate this opportunity?
# Answer: I won't invest because then again, I'm not really risk taker. If it's very uncertain, I would invest.
#
# Scenario 1 (Group 8):
# Main Question: How would you how do you balance work and personal life? Can you describe a typical day?
# Answer: Not very good at balancing it. Still learning, but I would try to maybe divide time, but not not very much.
# Follow-up Question: How often do you engage in social activities and what kind of activities do you prefer?
# Answer: Actually, I don't involve much in social activity. I'd like to be in my room watching series.
# Follow-up Question: Do you prefer structured routines or spontaneous activities and why?
# Answer: Structured routine with some spontaneous activities.
# Follow-up Question: How comfortable are you with taking risks? And can you share an example of a recent risk you took?
# Answer: Recent risk I took. I haven't taken it, but I want to rent a self drive that car and go roam around in that. But some people are not agreeing with it. But yeah.
# Follow-up Question: So you think you'll be comfortable with it because it's
# Answer: so risky? Yeah, because it is risky. But I know like the outcomes can be like I maybe I can crash it. But what can happen? I can crash it.
# Follow-up Question: How important are emotions in your decision making process? Can you provide an example?
# Answer: Not very emotional person. So I don't consider my emotion much. I suppress it mostly. More logical.
# Follow-up Question: So more logical approach. Okay. What strategies do you use to stay motivated when working towards a long term
# Answer: goal? Long term goal. I get distracted very easily. So for motivation, maybe the outcome can be my motivation. Like, I will achieve this. So that may it keep me motivated.
# Follow-up Question: How do you handle unexpected obstacles in your daily life? Can you provide an example?
# Answer: Unexpected obstacle. I would ignore it. Maybe it depends on the kind of obstacle actually.
# Follow-up Question: How important is it for you to maintain social connections and how do you nurture these relationships?
# Answer: Social connection. I'm not like very social person. So they're very fixed people that I hang out with. I like I don't very much feel like I'm the need to make new connections. So if I like the vibe, I will go with the floor. I won't talk to them much.
# Follow-up Question: How would you describe intense physical attraction and how can it be distinguished from deeper emotional connections like love or affection?
# Answer: Can you repeat?
# Follow-up Question: How would you describe intense physical attraction and how can it be distinguished from deeper emotional connections like love or affection?
# Answer: Okay. Physical love or affection is like very different from physical attraction. In physical attraction, you don't actually feel a connection. But in love you feel the connection.
# Follow-up Question: So do you think you can love without being physically attracted to somebody?
# Answer: If I if you're talking about like relationship, if I love someone, I think physical attraction comes along automatically. Like, if you like the personality, if you love them, you will automatically feel physical attraction.
# Follow-up Question: What are some effective ways to manage strong feelings of attraction particularly in context where they may not be appropriate? What are some effective ways to manage strong feelings of attraction particularly in context where they may not be appropriate?
# Answer: Attraction. I don't get attracted very easily. So, if it's not appropriate, I won't get attracted.
# Follow-up Question: Okay. Can you share an experience where a strong attraction influenced your choices and how did you navigate that situation?
# Answer: No. It never affected my situation.
# Follow-up Question: How often do you feel angry and what's typically triggers it for you?
# Answer: I don't get angry very easily. Like not very easily but if I get angry I would say very like mean things. So I try not to get angry, but if I get angry, it's very difficult to get back.
# Follow-up Question: So do you suppress your anger? Yes. Okay. How do you usually express your anger and what methods do you use to calm down?
# Answer: I try not to speak for some time.
# Follow-up Question: How do you calm down?
# Answer: I don't know. I don't speak for some time and then I, like, try to understand the other people's perspective. Okay. So they did this because maybe that was the reason and then I count on automatic.
# Follow-up Question: Can you provide an example of a situation where you managed your anger effectively?
# Answer: I try only. Like, I try to understand them, and I try not to speak. I don't know. I don't yeah. Even though I don't want to understand, I automatically try to understand. Like, it's okay. What's the point to say? Like, don't be the bad person.
# Follow-up Question: How do you define greed and in what ways do you see it manifest in your life?
# Answer: Greed. Like money. Money is important. Motivation maybe like for goals, need money.
# Follow-up Question: So how do you balance ambition and greed in your personal and professional life?
# Answer: I think they are very interconnected even for me. Like, ambition ambitious comes from me.
# Follow-up Question: Can you share an experience where greed negatively impacted your relationships or decisions?
# Answer: No. Like, I'm not that greedy. So
# Follow-up Question: How do you define attachment and how do you differentiate it from dependence?
# Answer: Attachment, for me is like connection. Like, when I feel good connection with them, but dependence is like when I trust the other person very much, then I feel very dependent on them. Like I can be dependent on them. But when I'm attached to someone, I'm not actually very dependent on them. There's just a connection. So how
# Follow-up Question: do you manage attachments in your life, especially in relationships?
# Answer: I don't get attached very easily. Like, I take a lot of time to get attached. So I don't know. It doesn't matter much. Like I can be attached also.
# Follow-up Question: Can you describe a situation where an attachment caused a challenge for you? How often do you experience feelings of jealousy and what usually triggers them?
# Answer: Jealousy jealousy, like, comes only when you, like, you have some sort of expectations. Like right? So I don't, like, feel like I don't think that I should expect something from everyone. So I feel like it's okay. Their life, it's okay.
# Follow-up Question: How do you cope with feelings of insecurity in your personal and professional life?
# Answer: I'm not, like, very insecure. I'm, like, more of a okay. I'm good. Like that only. So if I get insecure, I try to say, like, no, it's okay. I'm nice or it doesn't matter.
# Follow-up Question: Can you provide an example of how you overcame a situation where jealousy or insecurity was affecting you?
# Answer: I don't know. As I said, I suppress my feelings, so maybe I would ignore it. Something like
# Follow-up Question: that. So does it mean that you actually overcame
# Answer: Unfamiliar, maybe okay. So it depends on the situation, but if it's very unfamiliar, I would be a little scared. But it's okay. If it's unfamiliar, maybe it will teach me something. So a little excited. But scared.
# Follow-up Question: What strategies do you use to build confidence in areas where you feel less knowledgeable?
# Answer: If I feel less knowledgeable, then, yeah, then I would gain some knowledge. So that would be my confidence. Okay. I will gain something.
# Follow-up Question: Can you share a time when you successfully navigated an unknown situation and how you built your confidence to do so?
# Answer: So if there's an unfamiliar situation, I don't know. I haven't encountered much. Or if I ever encounter it, I try to escape from it or something like that because I live in the present, not in the future. I don't think about my future much. So, yeah, if I ever encounter it, I mean, depends on the situation also. But if I have to face it, then I would face it. Like, it's okay. I won't do it. Like, something like that.
# Follow-up Question: Do you feel this interview accurately captures your mental health and behavior?
# Answer: A little bit. Well, like fully, but yeah.
# Follow-up Question: Were you completely honest while answering? Yes. Did you at any point feel uncomfortable? Great. Thank you, Thalika.
# Answer: Thank you.
